# %%
import pandas as pd

mydataset = {'cars': ["BMW", "Volvo", "Ford"], 'passings': [3, 7, 2]
}
print(mydataset)
# Out:
# {'cars': ['BMW', 'Volvo', 'Ford'], 'passings': [3, 7, 2]}

# %%
myvar = pd.DataFrame(mydataset)

# %%
print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
import pandas as pd

a = [1, 7, 2]

myvar = pd.Series(a)

print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
print(myvar[1])
# Out:
# 7

# %%
myvar = pd.Series(a, index = ["x", "y", "z"])

# %%
print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
print(myvar["y"])
# Out:
# 7

# %%
import pandas as pd

calories = {"day1": 420, "day2": 380, "day3": 390,"day1": 999, "day5": 380, "day6": 390}

myvar = pd.Series(calories)

print(myvar)
# Out:
# day1    999
# day2    380
# day3    390
# day5    380
# day6    390
# dtype: int64

# %%
import pandas as pd

calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories, index = ["day3", "day2"])

print(myvar)
# Out:
# day3    390
# day2    380
# dtype: int64

# %%
import pandas as pd

data = { "calories": [420, 380, 390],  "duration": [50, 40, 45]}

myvar = pd.DataFrame(data,index = ["day1", "day2", "day3"])

print(myvar)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
#refer to the row index:
print(myvar.loc["day1"])
# Out:
# calories    420
# duration     50
# Name: day1, dtype: int64

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)

print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
#refer to the row index:
print(df.loc[0])
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64

# %%
#refer to the row index:
print(df.loc[1])
# Out:
# calories    380
# duration     40
# Name: 1, dtype: int64

# %%
#use a list of indexes:
print(df.loc[[2, 1]])
# Out:
#    calories  duration
# 2       390        45
# 1       380        40
